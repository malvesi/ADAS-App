# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.981 · TFM · Aula 1</p>
# <p style="margin: 0; text-align:right;">2024-2 · Màster universitari en Ciència de dades (Data science)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'informàtica, multimèdia i telecomunicació</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
# <div style="text-align: center; margin-top: 40px;">
#     <h1>Aplicación para ayuda a la conducción con deep learning</h1>
# </div>
#
# ### ARCHIVO 14: Programa principal main
#
# Código que evalua vídeos e imágenes con los modelos previamente entrenados y en función de parámetros archivo config.
#
# Código ejecutado en plataforma Visual Studio Code.

# %%
# Llibreries

from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
import yaml

# %%
# Configuració

with open("config.yaml", "r") as file:
    config = yaml.safe_load(file)

# %%
#Càrrega de paràmetres

#Funcionalitat
vehicles = config['functionality']['vehicles']
signs = config['functionality']['signs']
use_gpu = config['functionality']['use_gpu']

# Models
if vehicles:
    model_veh = YOLO(config['model_paths']['detect_vehicles'])          # Model detecció turismes i motos
    model_seg = YOLO(config['model_paths']['car_segment'])              # Model segmentació cotxes
    if use_gpu:                                                         # Model classificació frens
        model_bra = torch.load(config['model_paths']['brake_classifier'])
        model_bra = model_bra.cuda().eval()
    else:                     
        model_bra = torch.load(config['model_paths']['brake_classifier'], map_location=torch.device('cpu'))
        model_bra = model_bra.eval()
        
    # Transformació per model_bra
    transform_frens = transforms.Compose([
        transforms.ToTensor(),
        transforms.Resize((224, 224)),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
                            ])

if signs:
    model_sin = YOLO(config['model_paths']['traffic_signs'])             # Model detecció de semàfors i stops
    if use_gpu:                                                          # Model classificació de semàfors
        model_sem = torch.load(config['model_paths']['traffic_lights'])
        model_sem = model_sem.cuda().eval()
    else:
        model_sem = torch.load(config['model_paths']['traffic_lights'], map_location=torch.device('cpu'))
        model_sem = model_sem.eval()
        
    # Transformació per model_sem
    transform_semafor = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
                            ])
    
# Paràmetres
# Models
det_veh_conf = config['model_det_veh_param']['det_veh_conf']
det_veh_iou = config['model_det_veh_param']['det_veh_iou']
det_sig_conf = config['model_det_sig_param']['det_sig_conf']
det_sig_iou = config['model_det_sig_param']['det_sig_iou']
seg_car_conf = config['model_seg_car_param']['seg_car_conf']
seg_car_iou = config['model_seg_car_param']['seg_car_iou']
class_brake = config['model_cla_bra_param']['class_brake']
# Alarma
height_max = config['set_up_vehicle']['height']
x_position = config['set_up_vehicle']['x_position']

# %%
# Entrada

picture = None
video = None

try:
    #picture = cv2.imread(config['input']['picture'])
    picture = cv2.imread("V1.png")
except Exception as e:
    print("No s'ha pogut carregar la imatge")
    
try:
    video = cv2.VideoCapture(config['input']['video'])
    if not video.isOpened():
        raise FileNotFoundError("No s'ha pogut obrir el vídeo.")
except Exception as e:
    print("No s'ha pogut carregar el vídeo")
    
pic = picture is not None
vid = video is not None
# Out:
# No s'ha pogut carregar el vídeo

# %%
# Imatge
if pic:
    
    frame = picture
    
    # Vehicles
    if vehicles:
        
        # Detecció
        r_det_veh = model_veh(frame, conf=det_veh_conf, iou=det_veh_iou)[0]

        # Per detecció mostra per pantalla
        for box in r_det_veh.boxes:

            cls = int(box.cls[0])
            label = model_veh.names[cls]
            conf = box.conf[0]

            # Coordenades
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            x1, y1 = max(x1, 0), max(y1, 0)
            x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

            # Perill de col·lisió - Terç central? i Alçada bbox > 22%?
            width = frame.shape[1]
            height = frame.shape[0]

            center_x = (x1 + x2) / 2
            bbox_height = y2 - y1

            left_third = x_position / 2
            right_third = width + (x_position / 2)

            # Comprovació de perill
            perill = left_third <= center_x <= right_third and bbox_height > height_max * height

            if perill:
                cv2.putText(frame, "", (50, 100), #"PELIGRO  DE COLISION"
                    cv2.FONT_HERSHEY_SIMPLEX, 4, (0, 0, 255), 10)

            # Color de la bbox
            color = (0, 255, 255) if perill else (0, 254, 255)  # Vermell si perill, sinó groc

            
            # Dibuix bbox i text
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 5)
            label_text = f"{label}"
            cv2.putText(frame, label_text, (x1, y1 - 8),
                        cv2.FONT_HERSHEY_SIMPLEX, 3, color, 5)
   
            # Segmentació
            roi = frame[y1:y2, x1:x2]
            r_car_seg = model_seg(roi, conf=seg_car_conf, iou=seg_car_iou, verbose=False)[0]

            if r_car_seg.masks is not None: # Si segmenta, es mostren els resultats
                for i, mask in enumerate(r_car_seg.masks.data):
                    if i == 4 or i == 7 or i == 5:
                        mask_np = mask.cpu().numpy().astype("uint8") * 255
                        mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))

                        # Contorn
                        contours, _ = cv2.findContours(mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                        cv2.drawContours(roi, contours, -1, (0, 255, 0), 5) # Verd

                        # Nom
                        #part_label = model_seg.names[int(results_seg.boxes.cls[i])]
                        #M = cv2.moments(mask_resized)
                        #cX = int(M["m10"] / M["m00"])
                        #cY = int(M["m01"] / M["m00"])
                        #cv2.putText(roi, part_label, (cX - 10, cY), 
                                    #cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 10, cv2.LINE_AA) 

                        # Retalla part segmentada
                        seg_img = roi.copy()
                        seg_img[mask_resized == 0] = 0

                        # Prepara per inferència
                        #input_img = cv2.cvtColor(seg_img, cv2.COLOR_BGR2RGB)
                        #input_img = cv2.resize(input_img, (224, 224))
                        #input_tensor = transform2(input_img).unsqueeze(0).cuda()

                        with torch.no_grad():
                            output = model_bra(input_tensor)
                            prob = torch.sigmoid(output).item()
                            frenada = prob > 0.5

                        # Mostra resultat
                        status_text = "FRENA" if frenada else "NO FRENA"
                        color = (0, 0, 255) if frenada else (0, 255, 255)
                        cv2.putText(frame, status_text, (x1, y2 + 60),
                                    cv2.FONT_HERSHEY_SIMPLEX, 3, color, 6, cv2.LINE_AA)

                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
                        
    # Correcció BGR a RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Mostra la imatge
    plt.figure(figsize=(12, 8))
    plt.imshow(frame_rgb)
    plt.title("Detecció + segmentació")
    plt.show()
# Out:
# 0: 640x640 4 cars, 68.6ms
# Speed: 2.5ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Imatge a tractar
frame = cv2.imread("foto1.jpg")

# Detecció
results_det = model_det(frame)[0]

# Per detecció mostra per pantalla
for box in results_det.boxes:

    cls = int(box.cls[0])
    label = model_det.names[cls]
    conf = box.conf[0]
    
    # Coordenades
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    x1, y1 = max(x1, 0), max(y1, 0)
    x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

    # bbox + text
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 5)
    label_text = f"{label} {conf:.2f}"
    cv2.putText(frame, label_text, (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 255), 5)

    # Segmentació
    roi = frame[y1:y2, x1:x2] # ROI = Region of interest anomenat a la segmentació, regió de la imatge
    results_seg = model_seg(roi, conf=0.25, iou=0.4, verbose=False)[0]

    if results_seg.masks is not None: # Si segmenta, es mostren els resultats
        for i, mask in enumerate(results_seg.masks.data):
            if i == 4 or i == 7 or i == 5: # Únicament si són llums posteriors
                mask_np = mask.cpu().numpy().astype("uint8") * 255
                mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))
                                
                # Contorn
                contours, _ = cv2.findContours(mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                cv2.drawContours(roi, contours, -1, (0, 255, 0), 5) # Verd
                
                # Retalla part segmentada
                seg_img = roi.copy()
                seg_img[mask_resized == 0] = 0

                # Prepara per inferència
                input_img = cv2.cvtColor(seg_img, cv2.COLOR_BGR2RGB)
                input_img = cv2.resize(input_img, (224, 224))
                input_tensor = transform(input_img).unsqueeze(0).cuda()

                # Determina si frena o no
                with torch.no_grad():
                    output = model_bra(input_tensor)
                    prob = torch.sigmoid(output).item()
                    frenada = prob > 0.5

                # Mostra resultat
                status_text = "FRENA" if frenada else "NO FRENA"
                color = (0, 0, 255) if frenada else (0, 255, 255)
                cv2.putText(frame, status_text, (x1, y2 + 60),
                            cv2.FONT_HERSHEY_SIMPLEX, 3, color, 6, cv2.LINE_AA)

# Correcció BGR a RGB
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# Mostra la imatge
plt.figure(figsize=(12, 8))
plt.imshow(frame_rgb)
plt.title("Detecció + segmentació")
plt.show()
# Out:
# 0: 480x640 5 cars, 18.1ms
# Speed: 3.4ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Vídeo a tractar
video_path = "Media/v2.mp4"
cap = cv2.VideoCapture(video_path)

# Sortida
out = cv2.VideoWriter("sortida_segmentadav4.mp4",
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Per fotograma
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # DETECCIÓ de vehicles
    results_det = model_det(frame)[0]

    # Per detecció mostra per pantalla
    for box in results_det.boxes:

        cls = int(box.cls[0])
        label = model_det.names[cls]
        conf = box.conf[0]
    
        # Coordenades
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        x1, y1 = max(x1, 0), max(y1, 0)
        x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

        # bbox + text
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
        label_text = f"{label} {conf:.2f}"
        cv2.putText(frame, label_text, (x1, y1 - 8),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

        # Segmentació
        roi = frame[y1:y2, x1:x2] # ROI = Region of interest anomenat a la segmentació, regió de la imatge
        results_seg = model_seg(roi, verbose=False)[0]

        if results_seg.masks is not None: # Si segmenta, es mostren els resultats
            for i, mask in enumerate(results_seg.masks.data):
                if i == 4 or i == 7 or i == 5: # Únicament si són llums posteriors
                    mask_np = mask.cpu().numpy().astype("uint8") * 255
                    mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))
  
                    # Contorn
                    contours, _ = cv2.findContours(mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    cv2.drawContours(roi, contours, -1, (0, 255, 0), 2) # Verd
                    
                    # Retalla part segmentada
                    seg_img = roi.copy()
                    seg_img[mask_resized == 0] = 0

                    # Prepara per inferència
                    input_img = cv2.cvtColor(seg_img, cv2.COLOR_BGR2RGB)
                    input_img = cv2.resize(input_img, (224, 224))
                    input_tensor = transform(input_img).unsqueeze(0).cuda()

                    # Determina si frena o no
                    with torch.no_grad():
                        output = model_bra(input_tensor)
                        prob = torch.sigmoid(output).item()
                        frenada = prob > 0.5

                    # Mostra resultat
                    status_text = "FRENA" if frenada else "NO FRENA"
                    color = (0, 0, 255) if frenada else (0, 255, 255)
                    cv2.putText(frame, status_text, (x1, y2 + 60),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_AA)

    # Escriu el frame al vídeo sortida
    out.write(frame)

# Tanca arxiu
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 cars, 164.3ms
# Speed: 13.6ms preprocess, 164.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 2.7ms preprocess, 17.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.2ms
# Speed: 2.6ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.4ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.5ms
# Speed: 2.3ms preprocess, 19.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.2ms
# Speed: 2.5ms preprocess, 14.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.8ms
# Speed: 2.1ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.5ms preprocess, 14.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.2ms
# Speed: 2.6ms preprocess, 14.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.4ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.4ms
# Speed: 2.2ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.0ms
# Speed: 2.4ms preprocess, 14.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.7ms
# Speed: 2.6ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 2.6ms preprocess, 15.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.0ms
# Speed: 1.9ms preprocess, 18.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 5 cars, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 5 cars, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.9ms
# Speed: 1.8ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.6ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 32.6ms
# Speed: 2.3ms preprocess, 32.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
# 7
#
# 0: 384x640 6 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 4 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.5ms preprocess, 15.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.3ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
# 5
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
# 5
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
# 5
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
# 5
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.2ms preprocess, 14.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
# 4
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.3ms preprocess, 14.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 1.8ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 28.0ms
# Speed: 2.8ms preprocess, 28.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 13.9ms
# Speed: 2.1ms preprocess, 13.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 4 cars, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 4 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 5 cars, 18.1ms
# Speed: 2.6ms preprocess, 18.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 4 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 4 cars, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 13.9ms
# Speed: 2.8ms preprocess, 13.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.4ms
# Speed: 3.0ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.2ms
# Speed: 2.3ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.0ms
# Speed: 2.6ms preprocess, 16.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.8ms
# Speed: 3.3ms preprocess, 15.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 22.8ms
# Speed: 2.2ms preprocess, 22.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 19.5ms
# Speed: 2.3ms preprocess, 19.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.7ms
# Speed: 2.2ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.1ms
# Speed: 2.3ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 1.9ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.5ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.3ms
# Speed: 2.1ms preprocess, 14.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.2ms
# Speed: 2.2ms preprocess, 14.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.2ms
# Speed: 2.1ms preprocess, 14.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.6ms
# Speed: 2.3ms preprocess, 16.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 1.8ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.8ms
# Speed: 4.6ms preprocess, 20.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.9ms
# Speed: 2.5ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.3ms
# Speed: 2.4ms preprocess, 15.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.4ms
# Speed: 2.2ms preprocess, 14.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 2.6ms preprocess, 14.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 2 cars, 1 motorcycle, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 motorcycles, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.4ms
# Speed: 2.3ms preprocess, 14.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 2 motorcycles, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 3 motorcycles, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.6ms
# Speed: 2.0ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 14.5ms
# Speed: 2.1ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 19.0ms
# Speed: 2.3ms preprocess, 19.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.6ms
# Speed: 2.2ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 14.0ms
# Speed: 2.9ms preprocess, 14.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 14.5ms
# Speed: 2.2ms preprocess, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 motorcycle, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 14.0ms
# Speed: 2.2ms preprocess, 14.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 24.9ms
# Speed: 2.6ms preprocess, 24.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 15.0ms
# Speed: 2.6ms preprocess, 15.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.4ms
# Speed: 2.1ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 25.0ms
# Speed: 2.8ms preprocess, 25.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 2.0ms preprocess, 14.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 2.4ms preprocess, 18.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 19.3ms
# Speed: 3.0ms preprocess, 19.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.3ms
# Speed: 1.9ms preprocess, 14.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.2ms
# Speed: 2.7ms preprocess, 31.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 19.3ms
# Speed: 1.9ms preprocess, 19.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 2.3ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.9ms
# Speed: 2.1ms preprocess, 20.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.0ms
# Speed: 2.2ms preprocess, 21.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 31.9ms
# Speed: 2.9ms preprocess, 31.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 15.3ms preprocess, 38.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 14.6ms
# Speed: 2.1ms preprocess, 14.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.7ms
# Speed: 2.0ms preprocess, 23.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.1ms
# Speed: 2.1ms preprocess, 21.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.8ms
# Speed: 3.2ms preprocess, 21.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 3.3ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.9ms
# Speed: 2.3ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.0ms
# Speed: 2.3ms preprocess, 21.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 1.9ms preprocess, 17.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 1.9ms preprocess, 14.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.1ms
# Speed: 2.2ms preprocess, 53.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 23.6ms
# Speed: 2.5ms preprocess, 23.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 25.0ms
# Speed: 2.0ms preprocess, 25.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.0ms
# Speed: 1.8ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.9ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 2.3ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 88
#      86 cap.release()
#      87 out.release()
# ---> 88 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
