# %% [markdown]
# <div style="width: 100%; clear: both;">
# <div style="float: left; width: 50%;">
# <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
# </div>
# <div style="float: right; width: 50%;">
# <p style="margin: 0; padding-top: 22px; text-align:right;">M2.981 · TFM · Aula 1</p>
# <p style="margin: 0; text-align:right;">2024-2 · Màster universitari en Ciència de dades (Data science)</p>
# <p style="margin: 0; text-align:right; padding-button: 100px;">Estudis d'informàtica, multimèdia i telecomunicació</p>
# </div>
# </div>
# <div style="width:100%;">&nbsp;</div>
# <div style="text-align: center; margin-top: 40px;">
#     <h1>Aplicación para ayuda a la conducción con deep learning</h1>
# </div>
#
# ### ARCHIVO 8: Prueba modelo detección semáforos + STOPS
#
# Código que ejecuta en vídeos e imágenes del modelos entrenado para evaluar resultados.
#
# Código ejecutado en plataforma Visual Studio Code.

# %%
# Llibreries

from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Modelo
model_det = YOLO("Detect_SIGNS.pt")     # Model detecció semàfors + STOPS

# %%
# Imatge a tractar
frame = cv2.imread("Media/stop.jpg")

# Detecció
results_det = model_det(frame)[0]

# Per detecció mostra per pantalla
for box in results_det.boxes:

    cls = int(box.cls[0])
    label = model_det.names[cls]
    conf = box.conf[0]
    
    # Coordenades
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    x1, y1 = max(x1, 0), max(y1, 0)
    x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

    # bbox + text
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 5)
    label_text = f"{label} {conf:.2f}"
    cv2.putText(frame, label_text, (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 5)

# Correcció BGR a RGB
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# 📺 Mostra la imatge
plt.figure(figsize=(12, 8))
plt.imshow(frame_rgb)
plt.title("Detecció")
plt.show()
# Out:
# 0: 480x640 1 stop sign, 44.4ms
# Speed: 6.1ms preprocess, 44.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Imatge a tractar
frame = cv2.imread("Media/foto1.jpg")

# Detecció
results_det = model_det(frame)[0]

# Per detecció mostra per pantalla
for box in results_det.boxes:

    cls = int(box.cls[0])
    label = model_det.names[cls]
    conf = box.conf[0]
    
    # Coordenades
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    x1, y1 = max(x1, 0), max(y1, 0)
    x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

    # bbox + text
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 5)
    label_text = f"{label} {conf:.2f}"
    cv2.putText(frame, label_text, (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 5)

# Correcció BGR a RGB
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# 📺 Mostra la imatge
plt.figure(figsize=(12, 8))
plt.imshow(frame_rgb)
plt.title("Detecció")
plt.show()
# Out:
# 0: 480x640 1 traffic light, 1 stop sign, 47.9ms
# Speed: 4.7ms preprocess, 47.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)

# %%
# Video
cap = cv2.VideoCapture("Media/v2.mp4")

# Paràmetres vídeo
out = cv2.VideoWriter("sortida_senyals.mp4",
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Per fotograma
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # DETECCIÓ
    results_det = model_det(frame)[0]
    deteccions = results_det.boxes

    for box in deteccions:
        cls = int(box.cls[0])
        label = model_signs.names[cls]

        # Coordenades
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        x1, y1 = max(x1, 0), max(y1, 0)
        x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

        # bbox + text
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # Fotograma actualitzat
    out.write(frame)

# Allibera recursos
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 118.6ms
# Speed: 7.9ms preprocess, 118.6ms inference, 94.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 3.2ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.9ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 231.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.9ms preprocess, 17.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 2.4ms preprocess, 15.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.6ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.5ms preprocess, 39.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 2.3ms preprocess, 15.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 21.0ms
# Speed: 2.4ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 2.8ms preprocess, 14.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.7ms
# Speed: 2.2ms preprocess, 17.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.2ms
# Speed: 2.1ms preprocess, 35.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.1ms
# Speed: 2.7ms preprocess, 32.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 14.7ms
# Speed: 2.5ms preprocess, 14.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.2ms
# Speed: 2.5ms preprocess, 18.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.8ms
# Speed: 2.9ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.6ms preprocess, 15.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 22.9ms
# Speed: 2.1ms preprocess, 22.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 21.7ms
# Speed: 1.9ms preprocess, 21.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 22.5ms
# Speed: 2.8ms preprocess, 22.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 82.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.5ms
# Speed: 2.8ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.2ms
# Speed: 2.2ms preprocess, 19.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.5ms
# Speed: 2.5ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 20.9ms
# Speed: 2.8ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.5ms
# Speed: 2.5ms preprocess, 15.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.1ms
# Speed: 2.4ms preprocess, 21.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.3ms
# Speed: 2.6ms preprocess, 17.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.4ms
# Speed: 2.4ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.2ms
# Speed: 2.8ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 21.0ms
# Speed: 2.5ms preprocess, 21.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 57.3ms
# Speed: 2.3ms preprocess, 57.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.9ms
# Speed: 2.4ms preprocess, 17.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.4ms
# Speed: 2.7ms preprocess, 15.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.7ms
# Speed: 2.6ms preprocess, 15.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.3ms
# Speed: 2.7ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.9ms
# Speed: 2.4ms preprocess, 16.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.0ms
# Speed: 2.1ms preprocess, 21.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.6ms
# Speed: 2.1ms preprocess, 17.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 21.4ms
# Speed: 2.6ms preprocess, 21.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 15.7ms
# Speed: 3.2ms preprocess, 15.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 70.6ms
# Speed: 2.1ms preprocess, 70.6ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 37.7ms
# Speed: 2.6ms preprocess, 37.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 37.3ms
# Speed: 2.8ms preprocess, 37.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 37.7ms
# Speed: 2.9ms preprocess, 37.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 39.6ms
# Speed: 2.8ms preprocess, 39.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 39.7ms
# Speed: 2.7ms preprocess, 39.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 40.3ms
# Speed: 2.6ms preprocess, 40.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 37.2ms
# Speed: 2.8ms preprocess, 37.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 37.1ms
# Speed: 2.3ms preprocess, 37.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 36.7ms
# Speed: 2.8ms preprocess, 36.7ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 36.7ms
# Speed: 2.5ms preprocess, 36.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 traffic lights, 36.4ms
# Speed: 2.4ms preprocess, 36.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 36.4ms
# Speed: 2.7ms preprocess, 36.4ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 35.0ms
# Speed: 2.6ms preprocess, 35.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 37.2ms
# Speed: 2.4ms preprocess, 37.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 35.1ms
# Speed: 2.7ms preprocess, 35.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 35.1ms
# Speed: 2.6ms preprocess, 35.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 37.1ms
# Speed: 2.7ms preprocess, 37.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 traffic lights, 36.0ms
# Speed: 2.4ms preprocess, 36.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 36.2ms
# Speed: 3.6ms preprocess, 36.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 39.3ms
# Speed: 2.6ms preprocess, 39.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 15.2ms
# Speed: 2.5ms preprocess, 15.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 51.1ms
# Speed: 2.1ms preprocess, 51.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 traffic lights, 19.7ms
# Speed: 2.0ms preprocess, 19.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.3ms
# Speed: 2.4ms preprocess, 15.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 20.6ms
# Speed: 2.6ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 20.9ms
# Speed: 2.2ms preprocess, 20.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 33.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 15.7ms
# Speed: 8.5ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.4ms
# Speed: 2.2ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.4ms
# Speed: 2.7ms preprocess, 16.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.4ms
# Speed: 2.5ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 18.2ms
# Speed: 2.3ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 19.4ms
# Speed: 2.9ms preprocess, 19.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.2ms
# Speed: 3.1ms preprocess, 15.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 21.0ms
# Speed: 2.1ms preprocess, 21.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.9ms
# Speed: 2.5ms preprocess, 16.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 38.2ms
# Speed: 2.0ms preprocess, 38.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.1ms
# Speed: 3.0ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 18.0ms
# Speed: 2.2ms preprocess, 18.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 19.6ms
# Speed: 2.3ms preprocess, 19.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.4ms
# Speed: 2.3ms preprocess, 16.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 23.4ms
# Speed: 2.1ms preprocess, 23.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 17.8ms
# Speed: 2.1ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 19.5ms
# Speed: 2.1ms preprocess, 19.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 18.0ms
# Speed: 2.4ms preprocess, 18.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.3ms
# Speed: 2.4ms preprocess, 16.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 traffic lights, 22.8ms
# Speed: 2.0ms preprocess, 22.8ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 15.5ms
# Speed: 2.3ms preprocess, 15.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 traffic lights, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 15.6ms
# Speed: 2.4ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 20.7ms
# Speed: 3.5ms preprocess, 20.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.2ms
# Speed: 2.1ms preprocess, 17.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 32.2ms
# Speed: 2.1ms preprocess, 32.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.0ms
# Speed: 2.4ms preprocess, 16.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 traffic lights, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 14.7ms
# Speed: 2.7ms preprocess, 14.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.5ms
# Speed: 2.4ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.2ms
# Speed: 2.0ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 22.4ms
# Speed: 2.1ms preprocess, 22.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 20.6ms
# Speed: 2.1ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.2ms
# Speed: 2.5ms preprocess, 15.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 18.2ms
# Speed: 2.4ms preprocess, 18.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.7ms
# Speed: 2.2ms preprocess, 17.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.6ms
# Speed: 2.5ms preprocess, 16.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 22.3ms
# Speed: 2.2ms preprocess, 22.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 22.1ms
# Speed: 2.3ms preprocess, 22.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.8ms
# Speed: 2.7ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.6ms
# Speed: 2.6ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.9ms
# Speed: 2.5ms preprocess, 21.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 20.0ms
# Speed: 2.6ms preprocess, 20.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.5ms
# Speed: 2.7ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 23.9ms
# Speed: 2.7ms preprocess, 23.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 27.0ms
# Speed: 2.6ms preprocess, 27.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 19.1ms
# Speed: 2.2ms preprocess, 19.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.5ms
# Speed: 2.5ms preprocess, 19.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.3ms
# Speed: 2.4ms preprocess, 15.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 51.8ms
# Speed: 2.0ms preprocess, 51.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.1ms
# Speed: 2.6ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 14.8ms
# Speed: 2.6ms preprocess, 14.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 18.7ms
# Speed: 2.2ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.4ms
# Speed: 2.1ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 15.9ms
# Speed: 2.3ms preprocess, 15.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.3ms
# Speed: 1.9ms preprocess, 17.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 22.3ms
# Speed: 3.7ms preprocess, 22.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.3ms
# Speed: 2.3ms preprocess, 15.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 24.7ms
# Speed: 5.7ms preprocess, 24.7ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.3ms
# Speed: 3.5ms preprocess, 17.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.1ms
# Speed: 2.7ms preprocess, 17.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 32.3ms
# Speed: 2.6ms preprocess, 32.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.0ms
# Speed: 2.5ms preprocess, 16.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 3 traffic lights, 23.4ms
# Speed: 2.7ms preprocess, 23.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.9ms
# Speed: 2.4ms preprocess, 16.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 17.7ms
# Speed: 2.6ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 18.2ms
# Speed: 2.3ms preprocess, 18.2ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 21.2ms
# Speed: 3.3ms preprocess, 21.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 33.2ms
# Speed: 2.0ms preprocess, 33.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.5ms
# Speed: 2.2ms preprocess, 21.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 41.5ms
# Speed: 2.1ms preprocess, 41.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 16.7ms
# Speed: 3.4ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 traffic lights, 20.4ms
# Speed: 2.5ms preprocess, 20.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 traffic lights, 18.1ms
# Speed: 2.5ms preprocess, 18.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.5ms
# Speed: 2.4ms preprocess, 16.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.0ms
# Speed: 2.4ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 25.4ms
# Speed: 2.2ms preprocess, 25.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 22.7ms
# Speed: 2.6ms preprocess, 22.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.5ms
# Speed: 2.9ms preprocess, 21.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 27.7ms
# Speed: 1.9ms preprocess, 27.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 22.5ms
# Speed: 2.2ms preprocess, 22.5ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.5ms
# Speed: 2.2ms preprocess, 22.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 26.9ms
# Speed: 1.9ms preprocess, 26.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 15.2ms
# Speed: 2.8ms preprocess, 15.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 27.8ms
# Speed: 2.7ms preprocess, 27.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 traffic lights, 17.1ms
# Speed: 2.3ms preprocess, 17.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 27.1ms
# Speed: 2.0ms preprocess, 27.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 21.0ms
# Speed: 2.4ms preprocess, 21.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 18.8ms
# Speed: 2.7ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 47.8ms
# Speed: 2.4ms preprocess, 47.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.5ms
# Speed: 4.8ms preprocess, 21.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 20.6ms
# Speed: 1.9ms preprocess, 20.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 19.2ms
# Speed: 2.8ms preprocess, 19.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 21.0ms
# Speed: 2.1ms preprocess, 21.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.3ms
# Speed: 1.9ms preprocess, 21.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 36.8ms
# Speed: 2.4ms preprocess, 36.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 37.6ms
# Speed: 2.5ms preprocess, 37.6ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 43.4ms
# Speed: 3.3ms preprocess, 43.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 41.4ms
# Speed: 2.5ms preprocess, 41.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 43.7ms
# Speed: 2.6ms preprocess, 43.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 traffic lights, 39.0ms
# Speed: 3.6ms preprocess, 39.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 38.1ms
# Speed: 2.9ms preprocess, 38.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 36.8ms
# Speed: 3.4ms preprocess, 36.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 36.7ms
# Speed: 2.6ms preprocess, 36.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 2.6ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 36.3ms
# Speed: 2.6ms preprocess, 36.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 37.1ms
# Speed: 2.3ms preprocess, 37.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 35.6ms
# Speed: 3.3ms preprocess, 35.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.8ms
# Speed: 2.7ms preprocess, 36.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 75.8ms
# Speed: 3.2ms preprocess, 75.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 3.2ms preprocess, 38.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.7ms
# Speed: 2.6ms preprocess, 36.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 2.6ms preprocess, 37.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.2ms
# Speed: 2.5ms preprocess, 36.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 36.5ms
# Speed: 2.7ms preprocess, 36.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 37.1ms
# Speed: 2.4ms preprocess, 37.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.3ms
# Speed: 3.3ms preprocess, 34.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 38.3ms
# Speed: 2.7ms preprocess, 38.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.2ms
# Speed: 3.9ms preprocess, 36.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 2.8ms preprocess, 36.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.2ms
# Speed: 2.7ms preprocess, 19.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 23.4ms
# Speed: 2.1ms preprocess, 23.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 20.8ms
# Speed: 2.6ms preprocess, 20.8ms inference, 13.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 20.2ms
# Speed: 2.6ms preprocess, 20.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 26.7ms
# Speed: 1.9ms preprocess, 26.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 21.9ms
# Speed: 3.3ms preprocess, 21.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.5ms
# Speed: 1.9ms preprocess, 53.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 32.8ms
# Speed: 2.7ms preprocess, 32.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 22.0ms
# Speed: 2.6ms preprocess, 22.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.9ms
# Speed: 2.4ms preprocess, 19.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 21.6ms
# Speed: 2.4ms preprocess, 21.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 54.2ms
# Speed: 2.9ms preprocess, 54.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 traffic lights, 16.4ms
# Speed: 1.9ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 47
#      45 cap.release()
#      46 out.release()
# ---> 47 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'
