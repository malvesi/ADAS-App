# %%
from ultralytics import YOLO
import cv2
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import transforms

# 📦 Carrega els dos models
model_det = YOLO("Models/Detectvehicles.pt")   # Model que detecta cotxes i motos
model_seg = YOLO("Models/CarSegment.pt")  # Model que segmenta cotxes
model_bra = torch.load("Models/DetectBrake2.pt") # Model decisió binària fre.
model_bra = model_bra.cuda().eval()

# 🔄 Transformació per al model binari
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224, 224)),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# Imatge a tractar
frame = cv2.imread("5.jpg")

# Detecció
results_det = model_det(frame)[0]

# Per detecció mostra per pantalla
for box in results_det.boxes:

    cls = int(box.cls[0])
    label = model_det.names[cls]
    conf = box.conf[0]
    
    # Coordenades
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    x1, y1 = max(x1, 0), max(y1, 0)
    x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

    # bbox + text
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 5)
    label_text = f"{label} {conf:.2f}"
    cv2.putText(frame, label_text, (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 255), 5)

    # Segmentació
    roi = frame[y1:y2, x1:x2] # ROI = Region of interest anomenat a la segmentació, regió de la imatge
    results_seg = model_seg(roi, conf=0.25, iou=0.4, verbose=False)[0]

    if results_seg.masks is not None: # Si segmenta, es mostren els resultats
        for i, mask in enumerate(results_seg.masks.data):
            if i == 4 or i == 7 or i == 5:
                mask_np = mask.cpu().numpy().astype("uint8") * 255
                mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))
                
                print(i)
                
                # Contorn
                contours, _ = cv2.findContours(mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                cv2.drawContours(roi, contours, -1, (0, 255, 0), 5) # Verd

                # Nom
                #part_label = model_seg.names[int(results_seg.boxes.cls[i])]
                #M = cv2.moments(mask_resized)
                #cX = int(M["m10"] / M["m00"])
                #cY = int(M["m01"] / M["m00"])
                #cv2.putText(roi, part_label, (cX - 10, cY), 
                            #cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 10, cv2.LINE_AA) 
                
                # Retalla part segmentada
                seg_img = roi.copy()
                seg_img[mask_resized == 0] = 0

                # Prepara per inferència
                input_img = cv2.cvtColor(seg_img, cv2.COLOR_BGR2RGB)
                input_img = cv2.resize(input_img, (224, 224))
                input_tensor = transform(input_img).unsqueeze(0).cuda()

                with torch.no_grad():
                    output = model_bra(input_tensor)
                    prob = torch.sigmoid(output).item()
                    frenada = prob > 0.7

                # Mostra resultat
                status_text = "FRENA" if frenada else "NO FRENA"
                color = (0, 0, 255) if frenada else (0, 255, 255)
                cv2.putText(frame, status_text, (x1, y2 + 60),
                            cv2.FONT_HERSHEY_SIMPLEX, 3, color, 6, cv2.LINE_AA)

# Correcció BGR a RGB
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# 📺 Mostra la imatge
plt.figure(figsize=(12, 8))
plt.imshow(frame_rgb)
plt.title("Detecció + segmentació")
plt.show()
print(f"Partes detectades: {[model_seg.names[int(c)] for c in results_seg.boxes.cls]}")
# Out:
# 0: 480x640 4 cars, 40.5ms
# Speed: 8.3ms preprocess, 40.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# 4
# 5
# 7
# 4
# 5
# 7
# Partes detectades: []

# %%
# Imatge a tractar
frame = cv2.imread("foto1.jpg")

# Detecció
results_det = model_det(frame)[0]

# Per detecció mostra per pantalla
for box in results_det.boxes:

    cls = int(box.cls[0])
    label = model_det.names[cls]
    conf = box.conf[0]
    
    # Coordenades
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    x1, y1 = max(x1, 0), max(y1, 0)
    x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

    # bbox + text
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 5)
    label_text = f"{label} {conf:.2f}"
    cv2.putText(frame, label_text, (x1, y1 - 8),
                cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 255), 5)

    # Segmentació
    roi = frame[y1:y2, x1:x2] # ROI = Region of interest anomenat a la segmentació, regió de la imatge
    results_seg = model_seg(roi, conf=0.25, iou=0.4, verbose=False)[0]

    if results_seg.masks is not None: # Si segmenta, es mostren els resultats
        for i, mask in enumerate(results_seg.masks.data):
            if i == 4 or i == 7 or i == 5:
                mask_np = mask.cpu().numpy().astype("uint8") * 255
                mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))
                
                print(i)
                
                # Contorn
                contours, _ = cv2.findContours(mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                cv2.drawContours(roi, contours, -1, (0, 255, 0), 5) # Verd

                # Nom
                #part_label = model_seg.names[int(results_seg.boxes.cls[i])]
                #M = cv2.moments(mask_resized)
                #cX = int(M["m10"] / M["m00"])
                #cY = int(M["m01"] / M["m00"])
                #cv2.putText(roi, part_label, (cX - 10, cY), 
                            #cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 10, cv2.LINE_AA) 
                
                # Retalla part segmentada
                seg_img = roi.copy()
                seg_img[mask_resized == 0] = 0

                # Prepara per inferència
                input_img = cv2.cvtColor(seg_img, cv2.COLOR_BGR2RGB)
                input_img = cv2.resize(input_img, (224, 224))
                input_tensor = transform(input_img).unsqueeze(0).cuda()

                with torch.no_grad():
                    output = model_bra(input_tensor)
                    prob = torch.sigmoid(output).item()
                    frenada = prob > 0.5

                # Mostra resultat
                status_text = "FRENA" if frenada else "NO FRENA"
                color = (0, 0, 255) if frenada else (0, 255, 255)
                cv2.putText(frame, status_text, (x1, y2 + 60),
                            cv2.FONT_HERSHEY_SIMPLEX, 3, color, 6, cv2.LINE_AA)

# Correcció BGR a RGB
frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# 📺 Mostra la imatge
plt.figure(figsize=(12, 8))
plt.imshow(frame_rgb)
plt.title("Detecció + segmentació")
plt.show()
print(f"Partes detectades: {[model_seg.names[int(c)] for c in results_seg.boxes.cls]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Imatge a tractar
# ----> 2 frame = cv2.imread("foto1.jpg")
#       4 # Detecció
#       5 results_det = model_det(frame)[0]
#
# File c:\Users\malve\anaconda3\Lib\site-packages\ultralytics\utils\patches.py:30, in imread(filename, flags)
#      15 def imread(filename: str, flags: int = cv2.IMREAD_COLOR):
#      16     """
#      17     Read an image from a file.
#      18
#    (...)
#      28         >>> img = imread("path/to/image.jpg", cv2.IMREAD_GRAYSCALE)
#      29     """
# ---> 30     return cv2.imdecode(np.fromfile(filename, np.uint8), flags)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'foto1.jpg'

# %%
from ultralytics import YOLO
import cv2

# 📦 Carrega els dos models
model_det = YOLO("Models/Detectvehicles.pt")   # Model que detecta cotxes i motos
model_seg = YOLO("Models/CarSegment.pt")  # Model que segmenta cotxes

# 🎥 Llegeix el vídeo
video_path = "Media/v2.mp4"
cap = cv2.VideoCapture(video_path)

# 📽️ Paràmetres del vídeo de sortida
out = cv2.VideoWriter("sortida_segmentadav2_cm.mp4",
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# Processa cada frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # DETECCIÓ de vehicles
    results_det = model_det(frame)[0]
    deteccions = results_det.boxes

    for box in deteccions:
        cls = int(box.cls[0])
        label = model_det.names[cls]

        # Coordenades del bounding box
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        x1, y1 = max(x1, 0), max(y1, 0)
        x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

        # Aplica segmentació amb el model, independentment de la classe
        roi = frame[y1:y2, x1:x2]
        results_seg = model_seg(roi, verbose=False)[0]

        if results_seg.masks is not None:
            for mask in results_seg.masks.data:
                mask_np = mask.cpu().numpy().astype("uint8") * 255
                mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))
                if label == "car":
                    colored_mask = cv2.applyColorMap(mask_resized, cv2.COLORMAP_JET)
                else:
                    colored_mask = cv2.applyColorMap(mask_resized, cv2.COLORMAP_OCEAN)
                roi_overlay = cv2.addWeighted(roi, 0.6, colored_mask, 0.4, 0)
                frame[y1:y2, x1:x2] = roi_overlay

        # Dibuixa bounding box i etiqueta per TOTS els objectes
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

    # Guarda el frame processat
    out.write(frame)

# Allibera recursos
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 cars, 99.8ms
# Speed: 2.9ms preprocess, 99.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 36.2ms
# Speed: 2.6ms preprocess, 36.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.5ms
# Speed: 3.7ms preprocess, 15.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 18.0ms
# Speed: 2.3ms preprocess, 18.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 24.3ms
# Speed: 2.8ms preprocess, 24.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.2ms preprocess, 14.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.9ms
# Speed: 1.9ms preprocess, 15.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.9ms
# Speed: 2.1ms preprocess, 16.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.5ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.5ms preprocess, 14.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.4ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.7ms
# Speed: 2.7ms preprocess, 18.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.8ms
# Speed: 2.1ms preprocess, 20.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.8ms
# Speed: 2.1ms preprocess, 16.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.2ms preprocess, 15.2ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.5ms
# Speed: 2.0ms preprocess, 19.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.9ms preprocess, 15.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.2ms preprocess, 18.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.8ms
# Speed: 2.2ms preprocess, 14.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 1.9ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.2ms
# Speed: 2.7ms preprocess, 17.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.4ms
# Speed: 2.4ms preprocess, 16.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.7ms
# Speed: 2.2ms preprocess, 20.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.3ms
# Speed: 1.9ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.7ms
# Speed: 2.4ms preprocess, 14.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.8ms
# Speed: 2.2ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.8ms
# Speed: 2.4ms preprocess, 17.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.1ms
# Speed: 2.6ms preprocess, 16.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.3ms
# Speed: 2.1ms preprocess, 16.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.1ms
# Speed: 2.2ms preprocess, 18.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 33.8ms
# Speed: 2.0ms preprocess, 33.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.4ms
# Speed: 2.0ms preprocess, 15.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.2ms
# Speed: 2.1ms preprocess, 18.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.7ms
# Speed: 2.4ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.1ms
# Speed: 2.2ms preprocess, 17.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.9ms
# Speed: 2.2ms preprocess, 20.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.3ms
# Speed: 2.2ms preprocess, 15.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.7ms
# Speed: 2.2ms preprocess, 17.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.1ms preprocess, 15.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.6ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.7ms
# Speed: 2.1ms preprocess, 19.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.1ms
# Speed: 2.7ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.6ms
# Speed: 2.1ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.0ms
# Speed: 2.3ms preprocess, 15.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.1ms
# Speed: 2.1ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.5ms
# Speed: 2.2ms preprocess, 22.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.3ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.7ms
# Speed: 2.2ms preprocess, 19.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.0ms preprocess, 15.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.6ms
# Speed: 2.4ms preprocess, 14.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.1ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.4ms
# Speed: 2.7ms preprocess, 20.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.9ms
# Speed: 2.2ms preprocess, 16.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.3ms preprocess, 14.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.6ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 23.2ms
# Speed: 2.2ms preprocess, 23.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.5ms preprocess, 18.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.4ms preprocess, 15.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.7ms
# Speed: 2.3ms preprocess, 19.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.1ms
# Speed: 2.1ms preprocess, 19.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 2.2ms preprocess, 18.5ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 18.1ms
# Speed: 2.7ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.5ms
# Speed: 2.2ms preprocess, 17.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 21.7ms
# Speed: 2.0ms preprocess, 21.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.7ms
# Speed: 2.6ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 2.5ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.2ms
# Speed: 2.1ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.3ms
# Speed: 2.7ms preprocess, 14.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 1.9ms preprocess, 14.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.7ms
# Speed: 2.2ms preprocess, 15.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 21.1ms
# Speed: 2.1ms preprocess, 21.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.6ms
# Speed: 2.1ms preprocess, 49.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 15.0ms
# Speed: 3.2ms preprocess, 15.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 15.7ms
# Speed: 3.2ms preprocess, 15.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 motorcycle, 23.2ms
# Speed: 2.3ms preprocess, 23.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.8ms
# Speed: 2.2ms preprocess, 18.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 22.7ms
# Speed: 2.2ms preprocess, 22.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 21.6ms
# Speed: 2.3ms preprocess, 21.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.1ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.9ms
# Speed: 2.2ms preprocess, 15.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 19.8ms
# Speed: 4.1ms preprocess, 19.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.1ms
# Speed: 4.2ms preprocess, 17.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.2ms
# Speed: 2.8ms preprocess, 18.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.3ms
# Speed: 2.2ms preprocess, 17.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 19.1ms
# Speed: 2.2ms preprocess, 19.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 27.3ms
# Speed: 2.3ms preprocess, 27.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 19.3ms
# Speed: 2.2ms preprocess, 19.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.4ms
# Speed: 2.1ms preprocess, 20.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 34.3ms
# Speed: 2.6ms preprocess, 34.3ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.5ms
# Speed: 2.5ms preprocess, 17.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.3ms
# Speed: 2.6ms preprocess, 16.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 23.2ms
# Speed: 3.5ms preprocess, 23.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.6ms
# Speed: 3.4ms preprocess, 16.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.5ms
# Speed: 2.4ms preprocess, 18.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.6ms preprocess, 16.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.0ms
# Speed: 2.4ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 21.1ms
# Speed: 2.9ms preprocess, 21.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 28.1ms
# Speed: 2.2ms preprocess, 28.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 20.8ms
# Speed: 2.0ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 27.7ms
# Speed: 2.8ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 20.4ms
# Speed: 2.5ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.8ms
# Speed: 2.1ms preprocess, 17.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 2.2ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.4ms
# Speed: 2.1ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.7ms
# Speed: 2.4ms preprocess, 17.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 23.5ms
# Speed: 2.2ms preprocess, 23.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 27.9ms
# Speed: 4.8ms preprocess, 27.9ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.4ms
# Speed: 2.1ms preprocess, 18.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.1ms
# Speed: 2.1ms preprocess, 22.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 25.2ms
# Speed: 2.3ms preprocess, 25.2ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.7ms
# Speed: 2.1ms preprocess, 16.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.5ms
# Speed: 3.8ms preprocess, 18.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.3ms
# Speed: 3.4ms preprocess, 18.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 18.4ms
# Speed: 3.4ms preprocess, 18.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 25.7ms
# Speed: 2.3ms preprocess, 25.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.6ms
# Speed: 2.9ms preprocess, 19.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.0ms
# Speed: 2.8ms preprocess, 18.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 26.1ms
# Speed: 3.9ms preprocess, 26.1ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 19.3ms
# Speed: 2.3ms preprocess, 19.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 19.7ms
# Speed: 2.3ms preprocess, 19.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 2.1ms preprocess, 16.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 19.3ms
# Speed: 2.1ms preprocess, 19.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 14.9ms
# Speed: 2.6ms preprocess, 14.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.5ms
# Speed: 1.9ms preprocess, 15.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.1ms
# Speed: 2.7ms preprocess, 15.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.3ms
# Speed: 3.6ms preprocess, 20.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.7ms
# Speed: 2.1ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.8ms
# Speed: 3.5ms preprocess, 16.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.1ms
# Speed: 2.0ms preprocess, 17.1ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.4ms
# Speed: 2.3ms preprocess, 18.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.3ms
# Speed: 2.3ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 18.5ms
# Speed: 2.1ms preprocess, 18.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.4ms
# Speed: 1.8ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.7ms
# Speed: 2.2ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 20.2ms
# Speed: 2.3ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 15.4ms
# Speed: 3.6ms preprocess, 15.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 20.1ms
# Speed: 3.3ms preprocess, 20.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 22
3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 2.5ms preprocess, 40.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.3ms
# Speed: 2.5ms preprocess, 36.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.1ms
# Speed: 3.0ms preprocess, 68.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 2.5ms preprocess, 36.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.0ms
# Speed: 3.6ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 2.7ms preprocess, 37.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.7ms
# Speed: 3.2ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 2.4ms preprocess, 40.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 2.6ms preprocess, 38.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 2.5ms preprocess, 41.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 2.4ms preprocess, 38.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 2.6ms preprocess, 37.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.8ms
# Speed: 2.5ms preprocess, 43.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 6.5ms preprocess, 39.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.6ms
# Speed: 2.6ms preprocess, 38.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.5ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.9ms
# Speed: 2.5ms preprocess, 37.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.9ms
# Speed: 2.3ms preprocess, 40.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.0ms
# Speed: 2.7ms preprocess, 38.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 2.4ms preprocess, 39.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 2.6ms preprocess, 37.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.3ms
# Speed: 3.3ms preprocess, 36.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 3.0ms preprocess, 37.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 3.5ms preprocess, 39.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 motorcycle, 43.4ms
# Speed: 2.4ms preprocess, 43.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 motorcycles, 40.8ms
# Speed: 2.8ms preprocess, 40.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.9ms
# Speed: 4.1ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.5ms preprocess, 39.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 2.6ms preprocess, 37.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.2ms
# Speed: 2.7ms preprocess, 36.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.2ms
# Speed: 2.5ms preprocess, 36.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.4ms
# Speed: 2.8ms preprocess, 40.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 2.6ms preprocess, 39.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.7ms
# Speed: 2.6ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 2.5ms preprocess, 38.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.6ms
# Speed: 2.9ms preprocess, 39.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.5ms
# Speed: 2.5ms preprocess, 36.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 2.7ms preprocess, 38.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.4ms
# Speed: 2.5ms preprocess, 66.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 36.7ms
# Speed: 2.4ms preprocess, 36.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.5ms
# Speed: 2.9ms preprocess, 39.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 2.4ms preprocess, 37.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.8ms
# Speed: 2.6ms preprocess, 35.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 3.5ms preprocess, 40.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 2.6ms preprocess, 37.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 40.7ms
# Speed: 3.3ms preprocess, 40.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 2.4ms preprocess, 37.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 2.5ms preprocess, 37.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 36.2ms
# Speed: 2.5ms preprocess, 36.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 48.7ms
# Speed: 2.5ms preprocess, 48.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 46.8ms
# Speed: 2.8ms preprocess, 46.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 35.3ms
# Speed: 2.8ms preprocess, 35.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 2.5ms preprocess, 53.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.4ms
# Speed: 4.7ms preprocess, 43.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 39.7ms
# Speed: 5.1ms preprocess, 39.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.3ms
# Speed: 2.4ms preprocess, 45.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 63
#      61 cap.release()
#      62 out.release()
# ---> 63 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %%
# 🎥 Llegeix el vídeo
video_path = "Media/V3.mp4"
cap = cv2.VideoCapture(video_path)

# 📽️ Sortida
out = cv2.VideoWriter("V3bra.mp4",
                      cv2.VideoWriter_fourcc(*'mp4v'),
                      cap.get(cv2.CAP_PROP_FPS),
                      (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

# 🔁 Per cada frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # DETECCIÓ de vehicles
    results_det = model_det(frame)[0]

    # Per detecció mostra per pantalla
    for box in results_det.boxes:

        cls = int(box.cls[0])
        label = model_det.names[cls]
        conf = box.conf[0]
    
        # Coordenades
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        x1, y1 = max(x1, 0), max(y1, 0)
        x2, y2 = min(x2, frame.shape[1]), min(y2, frame.shape[0])

        # bbox + text
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
        label_text = f"{label} {conf:.2f}"
        cv2.putText(frame, label_text, (x1, y1 - 8),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2)

        # Segmentació
        roi = frame[y1:y2, x1:x2] # ROI = Region of interest anomenat a la segmentació, regió de la imatge
        results_seg = model_seg(roi, verbose=False)[0]

        if results_seg.masks is not None: # Si segmenta, es mostren els resultats
            for i, mask in enumerate(results_seg.masks.data):
                if i == 4 or i == 7 or i == 5:
                    mask_np = mask.cpu().numpy().astype("uint8") * 255
                    mask_resized = cv2.resize(mask_np, (x2 - x1, y2 - y1))
                
                    print(i)
                
                    # Contorn
                    contours, _ = cv2.findContours(mask_resized, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    cv2.drawContours(roi, contours, -1, (0, 255, 0), 2) # Verd

                    # Nom
                    #part_label = model_seg.names[int(results_seg.boxes.cls[i])]
                    #M = cv2.moments(mask_resized)
                    #cX = int(M["m10"] / M["m00"])
                    #cY = int(M["m01"] / M["m00"])
                    #cv2.putText(roi, part_label, (cX - 10, cY), 
                                #cv2.FONT_HERSHEY_SIMPLEX, 3, (0, 255, 0), 10, cv2.LINE_AA) 
                    
                    # Retalla part segmentada
                    seg_img = roi.copy()
                    seg_img[mask_resized == 0] = 0

                    # Prepara per inferència
                    input_img = cv2.cvtColor(seg_img, cv2.COLOR_BGR2RGB)
                    input_img = cv2.resize(input_img, (224, 224))
                    input_tensor = transform(input_img).unsqueeze(0).cuda()

                    with torch.no_grad():
                        output = model_bra(input_tensor)
                        prob = torch.sigmoid(output).item()
                        frenada = prob > 0.65

                    # Mostra resultat
                    status_text = "FRENA" if frenada else "NO FRENA"
                    color = (0, 0, 255) if frenada else (0, 255, 255)
                    cv2.putText(frame, status_text, (x1, y2 + 60),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_AA)

    # Escriu el frame al vídeo sortida
    out.write(frame)

# 🔚 Allibera
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 2 cars, 115.1ms
# Speed: 5.6ms preprocess, 115.1ms inference, 144.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 2 cars, 34.8ms
# Speed: 3.9ms preprocess, 34.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
#
# 0: 384x640 2 cars, 32.6ms
# Speed: 3.8ms preprocess, 32.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
# 4
#
# 0: 384x640 2 cars, 34.7ms
# Speed: 3.4ms preprocess, 34.7ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 33.9ms
# Speed: 7.4ms preprocess, 33.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
# 4
#
# 0: 384x640 2 cars, 32.5ms
# Speed: 3.4ms preprocess, 32.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 32.7ms
# Speed: 3.4ms preprocess, 32.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 2 cars, 32.6ms
# Speed: 3.8ms preprocess, 32.6ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 2 cars, 32.9ms
# Speed: 3.3ms preprocess, 32.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 33.1ms
# Speed: 3.5ms preprocess, 33.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 32.3ms
# Speed: 3.7ms preprocess, 32.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 33.1ms
# Speed: 3.7ms preprocess, 33.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 3 cars, 34.2ms
# Speed: 5.5ms preprocess, 34.2ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 34.0ms
# Speed: 3.4ms preprocess, 34.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 36.0ms
# Speed: 3.6ms preprocess, 36.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 34.9ms
# Speed: 3.3ms preprocess, 34.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 34.7ms
# Speed: 3.6ms preprocess, 34.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 3.4ms preprocess, 15.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 3.2ms preprocess, 16.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 2 cars, 23.5ms
# Speed: 4.3ms preprocess, 23.5ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 2 cars, 16.3ms
# Speed: 2.9ms preprocess, 16.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 3 cars, 16.3ms
# Speed: 3.0ms preprocess, 16.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 4
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 4.2ms preprocess, 15.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 33.7ms
# Speed: 3.2ms preprocess, 33.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 16.3ms
# Speed: 2.9ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 19.1ms
# Speed: 3.2ms preprocess, 19.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 5.5ms preprocess, 39.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 2 cars, 17.0ms
# Speed: 3.3ms preprocess, 17.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 18.9ms
# Speed: 3.2ms preprocess, 18.9ms inference, 15.2ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
# 7
# 4
#
# 0: 384x640 4 cars, 17.7ms
# Speed: 11.7ms preprocess, 17.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 19.7ms
# Speed: 2.8ms preprocess, 19.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 23.5ms
# Speed: 6.2ms preprocess, 23.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 19.4ms
# Speed: 3.8ms preprocess, 19.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
# 5
#
# 0: 384x640 4 cars, 19.2ms
# Speed: 3.5ms preprocess, 19.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 19.5ms
# Speed: 3.1ms preprocess, 19.5ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 21.3ms
# Speed: 4.8ms preprocess, 21.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 19.8ms
# Speed: 3.1ms preprocess, 19.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 14.0ms
# Speed: 3.2ms preprocess, 14.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 16.5ms
# Speed: 3.6ms preprocess, 16.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 18.3ms
# Speed: 3.4ms preprocess, 18.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 3.2ms preprocess, 14.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 3.7ms preprocess, 14.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 30.3ms
# Speed: 3.2ms preprocess, 30.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 20.3ms
# Speed: 2.9ms preprocess, 20.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 14.7ms
# Speed: 2.9ms preprocess, 14.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 2.9ms preprocess, 15.3ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 4
#
# 0: 384x640 2 cars, 18.3ms
# Speed: 3.5ms preprocess, 18.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 20.5ms
# Speed: 3.1ms preprocess, 20.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.9ms
# Speed: 3.7ms preprocess, 16.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 4.0ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 15.3ms
# Speed: 3.1ms preprocess, 15.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 16.4ms
# Speed: 3.6ms preprocess, 16.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 18.2ms
# Speed: 3.6ms preprocess, 18.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 4.1ms preprocess, 17.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 14.5ms
# Speed: 3.2ms preprocess, 14.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 4
# 5
#
# 0: 384x640 2 cars, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16
9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 22.7ms
# Speed: 3.0ms preprocess, 22.7ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 16.3ms
# Speed: 3.2ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 21.0ms
# Speed: 3.3ms preprocess, 21.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.0ms
# Speed: 3.7ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.8ms
# Speed: 3.1ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.6ms
# Speed: 3.5ms preprocess, 16.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.9ms
# Speed: 3.0ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 19.4ms
# Speed: 2.9ms preprocess, 19.4ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 17.1ms
# Speed: 3.1ms preprocess, 17.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.3ms
# Speed: 5.5ms preprocess, 28.3ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 19.6ms
# Speed: 3.7ms preprocess, 19.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 22.5ms
# Speed: 3.3ms preprocess, 22.5ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 25.8ms
# Speed: 2.8ms preprocess, 25.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.2ms
# Speed: 3.2ms preprocess, 15.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 27.8ms
# Speed: 3.9ms preprocess, 27.8ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 20.6ms
# Speed: 3.7ms preprocess, 20.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.3ms
# Speed: 3.3ms preprocess, 16.3ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 17.7ms
# Speed: 3.2ms preprocess, 17.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 19.0ms
# Speed: 2.8ms preprocess, 19.0ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.9ms
# Speed: 3.2ms preprocess, 18.9ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.4ms
# Speed: 2.8ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.2ms
# Speed: 3.4ms preprocess, 22.2ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 15.0ms
# Speed: 2.8ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.2ms
# Speed: 2.9ms preprocess, 15.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 15.7ms
# Speed: 2.9ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 3.0ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.6ms
# Speed: 3.1ms preprocess, 14.6ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.0ms
# Speed: 3.3ms preprocess, 19.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.8ms
# Speed: 3.0ms preprocess, 14.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.4ms
# Speed: 3.1ms preprocess, 17.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 19.1ms
# Speed: 2.8ms preprocess, 19.1ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.3ms
# Speed: 4.2ms preprocess, 17.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.3ms
# Speed: 2.8ms preprocess, 15.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.2ms
# Speed: 3.1ms preprocess, 16.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 29.6ms
# Speed: 4.1ms preprocess, 29.6ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 22.3ms
# Speed: 4.1ms preprocess, 22.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.3ms
# Speed: 3.0ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 19.9ms
# Speed: 2.9ms preprocess, 19.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 23.9ms
# Speed: 3.3ms preprocess, 23.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 20.1ms
# Speed: 3.6ms preprocess, 20.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.9ms
# Speed: 3.7ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 18.4ms
# Speed: 2.9ms preprocess, 18.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.7ms
# Speed: 2.8ms preprocess, 15.7ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 17.8ms
# Speed: 4.3ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 15.1ms
# Speed: 3.8ms preprocess, 15.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 18.6ms
# Speed: 4.3ms preprocess, 18.6ms inference, 17.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 17.6ms
# Speed: 2.9ms preprocess, 17.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 23.3ms
# Speed: 4.3ms preprocess, 23.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.5ms
# Speed: 3.2ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.8ms
# Speed: 3.1ms preprocess, 14.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.0ms
# Speed: 2.9ms preprocess, 18.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 15.3ms
# Speed: 2.9ms preprocess, 15.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 17.7ms
# Speed: 2.9ms preprocess, 17.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 20.8ms
# Speed: 3.0ms preprocess, 20.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 17.6ms
# Speed: 4.6ms preprocess, 17.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 29.8ms
# Speed: 3.1ms preprocess, 29.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 17.2ms
# Speed: 3.5ms preprocess, 17.2ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 22.5ms
# Speed: 4.5ms preprocess, 22.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.7ms
# Speed: 3.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 37.5ms
# Speed: 3.5ms preprocess, 37.5ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 24.7ms
# Speed: 3.2ms preprocess, 24.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 4
#
# 0: 384x640 3 cars, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 18.3ms
# Speed: 2.8ms preprocess, 18.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 16.1ms
# Speed: 2.9ms preprocess, 16.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 18.7ms
# Speed: 4.0ms preprocess, 18.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.5ms
# Speed: 3.1ms preprocess, 17.5ms inference, 18.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.9ms
# Speed: 3.3ms preprocess, 14.9ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.7ms
# Speed: 3.1ms preprocess, 14.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 15.6ms
# Speed: 2.9ms preprocess, 15.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 14.4ms
# Speed: 3.7ms preprocess, 14.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 17.7ms
# Speed: 3.0ms preprocess, 17.7ms inference, 19.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 21.1ms
# Speed: 2.9ms preprocess, 21.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 15.1ms
# Speed: 2.9ms preprocess, 15.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 23.1ms
# Speed: 3.8ms preprocess, 23.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 25.4ms
# Speed: 4.9ms preprocess, 25.4ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 28.6ms
# Speed: 2.9ms preprocess, 28.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 21.9ms
# Speed: 2.9ms preprocess, 21.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 17.3ms
# Speed: 2.8ms preprocess, 17.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 14.6ms
# Speed: 2.8ms preprocess, 14.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 20.3ms
# Speed: 3.1ms preprocess, 20.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 15.2ms
# Speed: 3.4ms preprocess, 15.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.2ms
# Speed: 2.7ms preprocess, 16.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 16.8ms
# Speed: 3.1ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 16.1ms
# Speed: 2.8ms preprocess, 16.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 88
#      86 cap.release()
#      87 out.release()
# ---> 88 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %% [markdown]
# # Inicio
# inicializar librerias
#
# # Cargar vídeo y configuracion
# Captura de vídeo
# Configuración general del programa
#
# # Bucle
# Mientras el vídeo esté activo:
#     leer frame
#
#     # Detección de objetos
#     Primera red detecta si hay vehículos
#     Segunda red detecta si hay señales
#
#     # Segmentación de imágenes
#     Se semgenta los elementos detectados
#
#     # Valoración individual
#     Se valora frenado o semáforo en rojo
#
#     # Valoración final
#     En función de las salidas en las redes, posiciones y tamaño
#     Se emite aviso o alerta.
#
#     # Generación de alerta
#     mostrar mensaje de alerta
#
# finalizar captura de vídeo y liberar recursos

# %%
import cv2
print(cv2.__file__)
# Out:
# c:\Users\malve\anaconda3\Lib\site-packages\cv2\__init__.py
